# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiraggzz/data-science-lab-1/blob/main/PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Create a DataFrame named student_df from a dictionary containing the columns Name, Age, and City for
# four students.

# %%
data = {
    "Name": ["Chirag", "Arav", "Abhishek", "Riya"],
    "Age": [20, 21, 30, 22],
    "City": ["Delhi", "Mumbai", "Agra", "Jaipur"]
}

student_df = pd.DataFrame(data)

# %% [markdown]
# 2. Display the complete student_df DataFrame.

# %%
print(student_df)
# Out:
#        Name  Age    City
# 0    Chirag   20   Delhi
# 1      Arav   21  Mumbai
# 2  Abhishek   30    Agra
# 3      Riya   22  Jaipur

# %% [markdown]
# 3. Write code to display the column names of student_df.

# %%
print(student_df.columns)
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %% [markdown]
# 4

# %%
print(student_df["Name"])
# Out:
# 0      Chirag
# 1        Arav
# 2    Abhishek
# 3        Riya
# Name: Name, dtype: object

# %% [markdown]
# 5

# %%
print(student_df["City"])
# Out:
# 0     Delhi
# 1    Mumbai
# 2      Agra
# 3    Jaipur
# Name: City, dtype: object

# %% [markdown]
# 6

# %%
new_df = student_df[["Name", "City"]]

print(new_df)
# Out:
#        Name    City
# 0    Chirag   Delhi
# 1      Arav  Mumbai
# 2  Abhishek    Agra
# 3      Riya  Jaipur

# %% [markdown]
# 7

# %%
book_data = {
    "Book": ["Python Basics", "DBMS", "Java", "C++"],
    "Author": ["CHIRAG", "CHIRAG2", "CHIRAG3", "CHIRAG4"],
    "Price": [3000, 4000, 35000, 4500]
}

book_df = pd.DataFrame(book_data)

print(book_df)
# Out:
#             Book   Author  Price
# 0  Python Basics   CHIRAG   3000
# 1           DBMS  CHIRAG2   4000
# 2           Java  CHIRAG3  35000
# 3            C++  CHIRAG4   4500

# %% [markdown]
# 8

# %%
book_df["Publisher"] = "CHIRAG Publications"

print(book_df)
# Out:
#             Book   Author  Price            Publisher
# 0  Python Basics   CHIRAG   3000  CHIRAG Publications
# 1           DBMS  CHIRAG2   4000  CHIRAG Publications
# 2           Java  CHIRAG3  35000  CHIRAG Publications
# 3            C++  CHIRAG4   4500  CHIRAG Publications

# %% [markdown]
# 9

# %%
df = pd.DataFrame(index=range(5))

df["SerialNo"] = np.arange(5)

print(df)
# Out:
#    SerialNo
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4

# %% [markdown]
# 10

# %%
df.drop('SerialNo', axis=1, inplace=True)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %% [markdown]
# 11

# %%
movie_data = {
    "Movie": ["3 Idiots", "Dangal", "PK", "Sholay"],
    "Year": [2009, 2016, 2014, 1975],
    "Rating": [8.4, 8.3, 8.1, 8.1]
}

movie_df = pd.DataFrame(movie_data)

print(movie_df)
# Out:
#       Movie  Year  Rating
# 0  3 Idiots  2009     8.4
# 1    Dangal  2016     8.3
# 2        PK  2014     8.1
# 3    Sholay  1975     8.1

# %% [markdown]
# 12

# %%
new_movie_df = movie_df[["Movie", "Rating"]].copy()

new_movie_df["Director"] = ["Rajkumar Hirani", "Nitesh Tiwari",
                            "Rajkumar Hirani", "Ramesh Sippy"]

print(new_movie_df)
# Out:
#       Movie  Rating         Director
# 0  3 Idiots     8.4  Rajkumar Hirani
# 1    Dangal     8.3    Nitesh Tiwari
# 2        PK     8.1  Rajkumar Hirani
# 3    Sholay     8.1     Ramesh Sippy

# %% [markdown]
# 13

# %%
city_series = pd.Series(
    ["Delhi", "Mumbai"],
    index=[0, 3]
)

print(city_series)
# Out:
# 0     Delhi
# 3    Mumbai
# dtype: object

# %% [markdown]
# 14

# %%
df = pd.DataFrame(index=range(4))

df["Branch"] = city_series

print(df)
# Out:
#    Branch
# 0   Delhi
# 1     NaN
# 2     NaN
# 3  Mumbai

# %% [markdown]
# 16

# %%
df = pd.DataFrame({
    'Name': ['A', 'B', 'C', 'D'],
    'Age': [20, 21, 19, 22]
})

branch = pd.Series(
    ['Delhi', 'Mumbai'],
    index=[0, 3]
)

df['Branch'] = branch

print(df)
# Out:
#   Name  Age  Branch
# 0    A   20   Delhi
# 1    B   21     NaN
# 2    C   19     NaN
# 3    D   22  Mumbai

# %% [markdown]
# 17

# %%
employee_df = pd.DataFrame({
    'Employee': ['Rahul', 'Aman', 'Priya', 'Neha', 'Karan'],
    'Department': ['IT', 'HR', 'Finance', 'IT', 'Marketing'],
    'Experience': [2, 4, 3, 5, 1]
})

new_employee_df = employee_df[['Employee', 'Experience']]

print(new_employee_df)
# Out:
#   Employee  Experience
# 0    Rahul           2
# 1     Aman           4
# 2    Priya           3
# 3     Neha           5
# 4    Karan           1

# %% [markdown]
# 18

# %%
print(employee_df['Department'])

print(employee_df.columns)
# Out:
# 0           IT
# 1           HR
# 2      Finance
# 3           IT
# 4    Marketing
# Name: Department, dtype: object
# Index(['Employee', 'Department', 'Experience'], dtype='object')

# %% [markdown]
# 19

# %%
employee_df['Office'] = 'Head Office'

print(employee_df)
# Out:
#   Employee Department  Experience       Office
# 0    Rahul         IT           2  Head Office
# 1     Aman         HR           4  Head Office
# 2    Priya    Finance           3  Head Office
# 3     Neha         IT           5  Head Office
# 4    Karan  Marketing           1  Head Office

# %% [markdown]
# 20

# %%
employee_df['Office'] = np.arange(5)

print(employee_df)
# Out:
#   Employee Department  Experience  Office
# 0    Rahul         IT           2       0
# 1     Aman         HR           4       1
# 2    Priya    Finance           3       2
# 3     Neha         IT           5       3
# 4    Karan  Marketing           1       4

# %% [markdown]
# 21

# %%
office_names = pd.Series(
    ['Delhi', 'Mumbai', 'Pune'],
    index=[0, 2, 4]
)

employee_df['Office'] = office_names

print(employee_df)
# Out:
#   Employee Department  Experience  Office
# 0    Rahul         IT           2   Delhi
# 1     Aman         HR           4     NaN
# 2    Priya    Finance           3  Mumbai
# 3     Neha         IT           5     NaN
# 4    Karan  Marketing           1    Pune

# %% [markdown]
# 22

# %%
employee_df = employee_df.drop('Office', axis=1)

print(employee_df)
# Out:
#   Employee Department  Experience
# 0    Rahul         IT           2
# 1     Aman         HR           4
# 2    Priya    Finance           3
# 3     Neha         IT           5
# 4    Karan  Marketing           1

# %% [markdown]
# 23

# %%
product_df = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Tablet', 'Watch'],
    'Category': ['Electronics', 'Electronics', 'Electronics', 'Accessories'],
    'Price': [60000, 30000, 25000, 10000]
})

new_product_df = product_df[['Price', 'Product', 'Category']]

print(new_product_df)
# Out:
#    Price Product     Category
# 0  60000  Laptop  Electronics
# 1  30000   Phone  Electronics
# 2  25000  Tablet  Electronics
# 3  10000   Watch  Accessories

# %% [markdown]
# 24

# %%
data = {
    'Name': ['Aman', 'Rahul', 'Priya'],
    'Age': [20, 21, 19],
    'City': ['Delhi', 'Pune', 'Mumbai']
}

df = pd.DataFrame(data)

new_df = df.reindex(columns=['Name', 'Age', 'City', 'Country'])

print(new_df)
# Out:
#     Name  Age    City  Country
# 0   Aman   20   Delhi      NaN
# 1  Rahul   21    Pune      NaN
# 2  Priya   19  Mumbai      NaN

# %% [markdown]
# 25

# %%
marks_df = pd.DataFrame({
    'Name': ['Aman', 'Rahul', 'Priya'],
    'Total Marks': [85, 90, 78]
})

print(marks_df['Total Marks'])
# Out:
# 0    85
# 1    90
# 2    78
# Name: Total Marks, dtype: int64

# %% [markdown]
# 26

# %% [markdown]
# 27

# %%
course_df = pd.DataFrame({
    'Student': ['Aman', 'Rahul', 'Priya', 'Neha', 'Karan'],
    'Course': ['Python', 'SQL', 'Java', 'Python', 'SQL'],
    'Score': [85, 78, 92, 88, 75]
})

# Display column names
print(course_df.columns)

# Retrieve Student
print(course_df['Student'])

# DataFrame containing Student and Score
student_score_df = course_df[['Student', 'Score']]

print(student_score_df)

# Add Batch column
course_df['Batch'] = 'BTech 2026'

print(course_df)
# Out:
# Index(['Student', 'Course', 'Score'], dtype='object')
# 0     Aman
# 1    Rahul
# 2    Priya
# 3     Neha
# 4    Karan
# Name: Student, dtype: object
#   Student  Score
# 0    Aman     85
# 1   Rahul     78
# 2   Priya     92
# 3    Neha     88
# 4   Karan     75
#   Student  Course  Score       Batch
# 0    Aman  Python     85  BTech 2026
# 1   Rahul     SQL     78  BTech 2026
# 2   Priya    Java     92  BTech 2026
# 3    Neha  Python     88  BTech 2026
# 4   Karan     SQL     75  BTech 2026

# %% [markdown]
# 28

# %%
travel_df = pd.DataFrame({
    'Name': ['Aman', 'Rahul', 'Priya', 'Neha', 'Karan'],
    'Destination': ['Delhi', 'Goa', 'Mumbai', 'Jaipur', 'Pune']
})

# Add Code using np.arange()
travel_df['Code'] = np.arange(5)

print("After np.arange():")
print(travel_df)

# Create partially indexed Series
codes = pd.Series(
    [101, 104],
    index=[1, 4]
)

# Replace Code column
travel_df['Code'] = codes

print("\nAfter Series assignment:")
print(travel_df)
# Out:
# After np.arange():
#     Name Destination  Code
# 0   Aman       Delhi     0
# 1  Rahul         Goa     1
# 2  Priya      Mumbai     2
# 3   Neha      Jaipur     3
# 4  Karan        Pune     4
#
# After Series assignment:
#     Name Destination   Code
# 0   Aman       Delhi    NaN
# 1  Rahul         Goa  101.0
# 2  Priya      Mumbai    NaN
# 3   Neha      Jaipur    NaN
# 4  Karan        Pune  104.0

# %% [markdown]
# 29

# %%
school_df = pd.DataFrame({
    'Student': ['Aman', 'Rahul', 'Priya', 'Neha'],
    'Class': [10, 10, 11, 11],
    'Section': ['A', 'B', 'A', 'B']
})

# Request House even though it doesn't exist
new_school_df = school_df.reindex(
    columns=['Student', 'Class', 'Section', 'House']
)

print("Before assigning House:")
print(new_school_df)

# Assign common value
new_school_df['House'] = 'Blue House'

print("\nAfter assigning House:")
print(new_school_df)
# Out:
# Before assigning House:
#   Student  Class Section  House
# 0    Aman     10       A    NaN
# 1   Rahul     10       B    NaN
# 2   Priya     11       A    NaN
# 3    Neha     11       B    NaN
#
# After assigning House:
#   Student  Class Section       House
# 0    Aman     10       A  Blue House
# 1   Rahul     10       B  Blue House
# 2   Priya     11       A  Blue House
# 3    Neha     11       B  Blue House

# %% [markdown]
# 30

# %%
inventory_df = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Tablet', 'Mouse', 'Keyboard'],
    'Quantity': [10, 20, 15, 30, 25],
    'Price': [60000, 30000, 25000, 800, 1200]
})

# Partially indexed Series
supplier = pd.Series(
    ['ABC Ltd', 'XYZ Ltd', 'PQR Ltd'],
    index=[0, 2, 4]
)

# Add column
inventory_df['Supplier'] = supplier

print("After adding Supplier:")
print(inventory_df)

# Delete column
inventory_df = inventory_df.drop('Supplier', axis=1)

print("\nAfter deleting Supplier:")
print(inventory_df)
# Out:
# After adding Supplier:
#     Product  Quantity  Price Supplier
# 0    Laptop        10  60000  ABC Ltd
# 1     Phone        20  30000      NaN
# 2    Tablet        15  25000  XYZ Ltd
# 3     Mouse        30    800      NaN
# 4  Keyboard        25   1200  PQR Ltd
#
# After deleting Supplier:
#     Product  Quantity  Price
# 0    Laptop        10  60000
# 1     Phone        20  30000
# 2    Tablet        15  25000
# 3     Mouse        30    800
# 4  Keyboard        25   1200
